# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.regressionplots import influence_plot
import statsmodels.formula.api as smf #for slr only this is enough
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-1c72cbbf-ed8a-4868-806e-d6fced20f836" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1c72cbbf-ed8a-4868-806e-d6fced20f836">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
st=pd.read_csv('50_startups.csv')
st
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
#eda
st.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
sta=st.rename({'R&D Spend':'RDS','Administration':'ADMS','Marketing Spend':'MKTS'},axis=1)
sta
# Out:
#           RDS       ADMS       MKTS       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
sta[sta.duplicated()] 
# No duplicated data
# Out:
# Empty DataFrame
# Columns: [RDS, ADMS, MKTS, State, Profit]
# Index: []

# %%
sta.describe()
# Out:
#                  RDS           ADMS           MKTS         Profit
# count      50.000000      50.000000      50.000000      50.000000
# mean    73721.615600  121344.639600  211025.097800  112012.639200
# std     45902.256482   28017.802755  122290.310726   40306.180338
# min         0.000000   51283.140000       0.000000   14681.400000
# 25%     39936.370000  103730.875000  129300.132500   90138.902500
# 50%     73051.080000  122699.795000  212716.240000  107978.190000
# 75%    101602.800000  144842.180000  299469.085000  139765.977500
# max    165349.200000  182645.560000  471784.100000  192261.830000

# %%
#Correlation Analysis
sta.corr()
# Out:
#              RDS      ADMS      MKTS    Profit
# RDS     1.000000  0.241955  0.724248  0.972900
# ADMS    0.241955  1.000000 -0.032154  0.200717
# MKTS    0.724248 -0.032154  1.000000  0.747766
# Profit  0.972900  0.200717  0.747766  1.000000

# %%
sns.set_style(style='whitegrid') #or style can be ticks /darkgrid
sns.pairplot(sta)

# %%
sns.set_style(style='ticks')
sns.pairplot(sta)

# %%
#model building
model=smf.ols('Profit~RDS+ADMS+MKTS',data=sta).fit()
model

# %%
#model testing
# Finding Coefficient parameters
model.params
# Out:
# Intercept    50122.192990
# RDS              0.805715
# ADMS            -0.026816
# MKTS             0.027228
# dtype: float64

# %%
# Finding tvalues and pvalues
model.tvalues , np.round(model.pvalues,5)
# Out:
# (Intercept     7.626218
#  RDS          17.846374
#  ADMS         -0.525507
#  MKTS          1.655077
#  dtype: float64, Intercept    0.00000
#  RDS          0.00000
#  ADMS         0.60176
#  MKTS         0.10472
#  dtype: float64)

# %%
#the variables with mav p values are adms and mkts..so those are the insignificant independent variables

# %%
# Finding rsquared values
model.rsquared
# Out:
# 0.9507459940683246

# %%
# Build SLR and MLR models for insignificant variables 'ADMS' and 'MKTS'
# Also find their tvalues and pvalues

# %%
slr_a=smf.ols("Profit~ADMS",data=sta).fit()
slr_a.tvalues , slr_a.pvalues  # ADMS has in-significant pvalue
# Out:
# (Intercept    3.040044
#  ADMS         1.419493
#  dtype: float64, Intercept    0.003824
#  ADMS         0.162217
#  dtype: float64)

# %%
slr_a=smf.ols("Profit~MKTS",data=sta).fit()
slr_a.tvalues , slr_a.pvalues #MTKS has significant p value
# Out:
# (Intercept    7.808356
#  MKTS         7.802657
#  dtype: float64, Intercept    4.294735e-10
#  MKTS         4.381073e-10
#  dtype: float64)

# %%
slr_a=smf.ols("Profit~ADMS+MKTS",data=sta).fit()
slr_a.tvalues , slr_a.pvalues #variables have significant pvalues
# Out:
# (Intercept    1.142741
#  ADMS         2.467779
#  MKTS         8.281039
#  dtype: float64, Intercept    2.589341e-01
#  ADMS         1.729198e-02
#  MKTS         9.727245e-11
#  dtype: float64)

# %%
#Model Validation
#Two Techniques: 1. Collinearity Check & 2. Residual Analysis
# 1) Collinearity Problem Check
# Calculate VIF = 1/(1-Rsquare) for all independent variables

rsq_r=smf.ols("RDS~ADMS+MKTS",data=sta).fit().rsquared
vif_r=1/(1-rsq_r)

rsq_a=smf.ols("ADMS~RDS+MKTS",data=sta).fit().rsquared
vif_a=1/(1-rsq_a)

rsq_m=smf.ols("MKTS~RDS+ADMS",data=sta).fit().rsquared
vif_m=1/(1-rsq_m)

# Putting the values in Dataframe format
d1={'Variables':['RDS','ADMS','MKTS'],'Vif':[vif_r,vif_a,vif_m]}
Vif_df=pd.DataFrame(d1)
Vif_df
# Out:
#   Variables       Vif
# 0       RDS  2.468903
# 1      ADMS  1.175091
# 2      MKTS  2.326773

# %%
# None variable has VIF>3, No Collinearity, so consider all varaibles in Regression equation

# %%
#2.residual analysis

# %%
#checking normality of errors

# %%
sns.boxplot(model.resid)

# %%
sns.histplot(model.resid)

# %%
sns.distplot(model.resid)

# %%
def get_standardized_values(vals):return(vals-vals.mean()/vals.std())

# %%
plt.scatter(get_standardized_values(model.fittedvalues),get_standardized_values(model.resid))
plt.title('residual_analysis')
plt.xlabel('std_fitted_vals')
plt.ylabel('std_resid_vals')
# Out:
# Text(0, 0.5, 'std_resid_vals')

# %%
plt.scatter(get_standardized_values(sta['ADMS']),get_standardized_values(model.resid))
plt.title('residual_analysis')
plt.xlabel('std_independent_values')
plt.ylabel('std_resid_vals')
# Out:
# Text(0, 0.5, 'std_resid_vals')

# %%
plt.scatter(get_standardized_values(sta['RDS']),get_standardized_values(model.resid))
plt.title('residual_analysis')
plt.xlabel('std_independent_values')
plt.ylabel('std_resid_vals')
# Out:
# Text(0, 0.5, 'std_resid_vals')

# %%
plt.scatter(get_standardized_values(sta['MKTS']),get_standardized_values(model.resid))
plt.title('residual_analysis')
plt.xlabel('std_independent_values')
plt.ylabel('std_resid_vals')
# Out:
# Text(0, 0.5, 'std_resid_vals')

# %%
#model deletion diagnostics
(c,_)=model.get_influence().cooks_distance
c
# Out:
# array([3.21825244e-05, 3.27591036e-03, 3.23842699e-02, 2.17206555e-02,
#        1.44833032e-02, 1.17158463e-02, 2.91766303e-03, 3.56513444e-03,
#        4.04303948e-05, 4.86758017e-03, 1.51064757e-02, 1.63564959e-02,
#        1.15516625e-02, 4.01422811e-03, 6.12934253e-02, 3.40013448e-02,
#        8.33556413e-03, 3.30534399e-03, 2.16819303e-03, 4.07440577e-02,
#        4.25137222e-04, 1.09844352e-02, 2.91768000e-03, 2.76030254e-04,
#        5.04643588e-03, 3.00074623e-03, 3.41957068e-03, 2.98396413e-02,
#        1.31590664e-03, 1.25992620e-04, 4.18505125e-05, 9.27434786e-06,
#        7.08656521e-04, 1.28122674e-04, 2.09815032e-02, 6.69508674e-03,
#        5.55314705e-02, 6.55050578e-05, 5.61547311e-02, 1.54279607e-03,
#        1.84850929e-03, 1.97578066e-03, 1.36089280e-04, 2.05553171e-02,
#        1.23156041e-04, 9.03234206e-02, 5.45303387e-02, 5.33885616e-03,
#        1.90527441e-01, 2.88082293e-01])

# %%
# Plot the influencers using the stem plot
fig=plt.figure(figsize=(20,7))
plt.stem(np.arange(len(sta)),np.round(c,5))
plt.xlabel('Row Index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
# Index and value of influencer where C>0.5
np.argmax(c) , np.max(c)
# Out:
# (49, 0.2880822927543272)

# %%
# 2. Leverage Value using High Influence Points : Points beyond Leverage_cutoff value are influencers
influence_plot(model)
plt.show()

# %%
# Leverage Cuttoff Value = 3*(k+1)/n ; k = no.of features/columns & n = no. of datapoints
k=3
n=50
leverage_cutoff = (3*(k+1))/n
leverage_cutoff
# Out:
# 0.24

# %%
sta[sta.index.isin([49])]
# Out:
#     RDS      ADMS      MKTS       State   Profit
# 49  0.0  116983.8  45173.06  California  14681.4

# %%
# Discard the data points which are influencers and reassign the row number (reset_index(drop=True))
sat=sta.drop(sta.index[[49]],axis=0).reset_index(drop=True)
sat
# Out:
#           RDS       ADMS       MKTS       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
while np.max(c)>0.5 :
    model=smf.ols("Profit~RDS+ADMS+MKTS",data=sat).fit()
    (c,_)=model.get_influence().cooks_distance
    c
    np.argmax(c) , np.max(c)
    sat=sat.drop(sat.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
    sat
else:
    final_model=smf.ols("Profit~RDS+ADMS+MKTS",data=sat).fit()
    final_model.rsquared , final_model.aic
    print("Thus model accuracy is improved to",final_model.rsquared)
# Out:
# Thus model accuracy is improved to 0.9613162435129848

# %%
final_model.rsquared
# Out:
# 0.9613162435129848

# %%
sat['pred_y']=final_model.predict(sat)
sat
# Out:
#           RDS       ADMS       MKTS       State     Profit         pred_y
# 0   165349.20  136897.80  471784.10    New York  192261.83  190716.676999
# 1   162597.70  151377.59  443898.53  California  191792.06  187537.122227
# 2   153441.51  101145.55  407934.54     Florida  191050.39  180575.526396
# 3   144372.41  118671.85  383199.62    New York  182901.99  172461.144642
# 4   142107.34   91391.77  366168.42     Florida  166187.94  170863.486721
# 5   131876.90   99814.71  362861.36    New York  156991.12  162582.583177
# 6   134615.46  147198.87  127716.82  California  156122.51  157741.338633
# 7   130298.13  145530.06  323876.68     Florida  155752.60  159347.735318
# 8   120542.52  148718.95  311613.29    New York  152211.77  151328.826941
# 9   123334.88  108679.17  304981.62  California  149759.96  154236.846778
# 10  101913.08  110594.11  229160.95     Florida  146121.95  135507.792682
# 11  100671.96   91790.61  249744.55  California  144259.40  135472.855621
# ...

# %%
#table containing R^2 value for each prepared model
d2={'Prep_Models':['Model','Final_Model'],'Rsquared':[model.rsquared,final_model.rsquared]}
table=pd.DataFrame(d2)
table
# Out:
#    Prep_Models  Rsquared
# 0        Model  0.950746
# 1  Final_Model  0.961316
